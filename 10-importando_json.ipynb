# %%
import pandas as pd

# %%
df = pd.read_json('dados/receitas.json', encoding='utf-8')
df
# Out:
#                                             receitas
# 0  {'titulo': 'Bolo de chololate', 'tempo_preparo...
# 1  {'titulo': 'Salada Caesar', 'tempo_preparo': '...
# 2  {'titulo': 'Pasta ao Pesto', 'tempo_preparo': ...

# %%
df_receitas = pd.json_normalize(
    df['receitas'],
    'ingredientes',
    ['titulo', 'tempo_preparo','porcoes']
)

# %%
df_receitas
# Out:
#                ingrediente  quantidade             titulo tempo_preparo  \
# 0         Farinha de trigo   2 xicaras  Bolo de chololate    45 minutos
# 1                   Acucar    1 xicara  Bolo de chololate    45 minutos
# 2                     Ovos  3 unidades  Bolo de chololate    45 minutos
# 3                    leite   1 xicaras  Bolo de chololate    45 minutos
# 4                 Manteiga  1/2 xicara  Bolo de chololate    45 minutos
# 5            Alface romana    1 cabeça      Salada Caesar    20 minutos
# 6                 Croutons    1 xicara      Salada Caesar    20 minutos
# 7   Queijo parmesao ralado  1/2 xicara      Salada Caesar    20 minutos
# 8             Molho Caesar  1/4 xicara      Salada Caesar    20 minutos
# 9     Massa de sua escolha        300g     Pasta ao Pesto    30 minutos
# 10                    Alho    2 dentes     Pasta ao Pesto    30 minutos
# 11                   Pesto  1/4 xicara     Pasta ao Pesto    30 minutos
# 12  Queijo parmesao ralado  1/2 xicara     Pasta ao Pesto    30 minutos
#
#    porcoes
# 0        8
# 1        8
# 2        8
# 3        8
# 4        8
# 5        4
# 6        4
# 7        4
# 8        4
# 9        4
# 10       4
# 11       4
# 12       4
